# %%
import pandas as pd
print(f'from python {pd}')
from matplotlib import pyplot as pp
df = pd.DataFrame(dict(
  x=range(9)
  ))
df.plot()
#pp.plot(range(9))
#pp.show()
# Out:
# from python <module 'pandas' from '/usr/local/lib/python3.8/dist-packages/pandas/__init__.py'>
# <AxesSubplot:>
